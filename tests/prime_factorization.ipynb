# %%
from dlqpiler.main import *

# %%
txt = '''
    p1[4] in {2, 3, 5, 7};
    p2[4] in {2, 3, 5, 7};
    y[1] := p1*p2=15;
    amplify y 2 times
'''

# %%
psim(txt, shots=1024)
# Out:
#     p1  p2  y  $freq
# 0    3   5  1    466
# 1    5   3  1    458
# 2    2   2  0     11
# 3    3   7  0     10
# 4    5   7  0     10
# 5    3   2  0      9
# 6    5   2  0      8
# 7    2   7  0      8
# 8    7   3  0      7
# 9    5   5  0      7
# 10   7   2  0      6
# 11   3   3  0      5
# 12   7   7  0      5
# 13   7   5  0      5
# 14   2   3  0      5
# 15   2   5  0      4

# %%
get_qqc(txt).draw(output='mpl')
